# %%
# 1 - Confirming that pandas is available
import pandas as pd

print(pd.__version__)
# Out:
# 2.2.2

# %%
# 2 - Create a Sales Data CSV File

from random import randint
from datetime import date

def create_sales_data(file_name):
    header_row = ['product_id','customer_id','sales_date','quantity','price']
    data_rows = []
    for i in range(65,91): # for 26 letters to make it 26 products
        details = [f'Product {chr(i)}', f'CUST {(i+2)%70 + 1}', f'{date(2026,1,(i-60))}', f'{randint(10, 200)}', f'{randint(500,10000)}']
        data_rows.append(details)

        # print(details)
    # print(data_rows)
    df = pd.DataFrame(data_rows, columns=header_row)
    df.to_csv(file_name, index=False)
    print(f"\n{file_name} creation done.")

create_sales_data('sales_data_2.csv')
# Out:
# sales_data_2.csv creation done.

# %%
# Wanted to learn how date function works
from datetime import date

# print(date(1))
# print(date(1,1))
print(date(2,1,1))
# Out:
# 0002-01-01

# %%
# 3 - Load the CSV File into a Pandas DataFrame

sales_data = pd.read_csv('sales_data_2.csv')
print(sales_data)
# Out:
#    product_id customer_id  sales_date  quantity  price
# 0   Product A     CUST 68  2026-01-05       137   4266
# 1   Product B     CUST 69  2026-01-06        60   2217
# 2   Product C     CUST 70  2026-01-07        51   1191
# 3   Product D      CUST 1  2026-01-08        16   5609
# 4   Product E      CUST 2  2026-01-09       154   5994
# 5   Product F      CUST 3  2026-01-10       186   4340
# 6   Product G      CUST 4  2026-01-11        36   5478
# 7   Product H      CUST 5  2026-01-12        62   2447
# 8   Product I      CUST 6  2026-01-13       200   2831
# 9   Product J      CUST 7  2026-01-14       148   7361
# 10  Product K      CUST 8  2026-01-15       121   2174
# 11  Product L      CUST 9  2026-01-16        23   2968
# 12  Product M     CUST 10  2026-01-17        99   5613
# 13  Product N     CUST 11  2026-01-18        85   3399
# 14  Product O     CUST 12  2026-01-19       114   3921
# 15  Product P     CUST 13  2026-01-20       119   2883
# ...

# %%
# 4 - Inspect the DataFrame

sales_data = pd.read_csv('sales_data_2.csv')

print(sales_data.head())
print()
print(sales_data.info())
print()
print(sales_data.describe())
# Out:
#   product_id customer_id  sales_date  quantity  price
# 0  Product A     CUST 68  2026-01-05       137   4266
# 1  Product B     CUST 69  2026-01-06        60   2217
# 2  Product C     CUST 70  2026-01-07        51   1191
# 3  Product D      CUST 1  2026-01-08        16   5609
# 4  Product E      CUST 2  2026-01-09       154   5994
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product_id   26 non-null     object
#  1   customer_id  26 non-null     object
#  2   sales_date   26 non-null     object
#  3   quantity     26 non-null     int64
#  4   price        26 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 1.1+ KB
# None
#
#          quantity        price
# count   26.000000    26.000000
# mean   107.884615  4570.153846
# std     51.712534  2370.025024
# min     16.000000   889.000000
# ...

# %%
# 5 - Specify Data Types

sales_data = pd.read_csv('sales_data_2.csv', dtype={'product_id': str, 'customer_id': str, 'price': float})

print(sales_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product_id   26 non-null     object
#  1   customer_id  26 non-null     object
#  2   sales_date   26 non-null     object
#  3   quantity     26 non-null     int64
#  4   price        26 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.1+ KB
# None

# %%
# 6 - Handle Dates

sales_data = pd.read_csv('sales_data_2.csv', parse_dates=['sales_date'])

print(sales_data.info())
# print(sales_data['sales_date'].dt.year)
# print(sales_data['sales_date'].dt.month)
print(sales_data['sales_date'].dt.day)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product_id   26 non-null     object
#  1   customer_id  26 non-null     object
#  2   sales_date   26 non-null     datetime64[ns]
#  3   quantity     26 non-null     int64
#  4   price        26 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 1.1+ KB
# None
# 0     2026
# 1     2026
# 2     2026
# 3     2026
# 4     2026
# 5     2026
# 6     2026
# 7     2026
# 8     2026
# 9     2026
# 10    2026
# 11    2026
# 12    2026
# 13    2026
# 14    2026
# 15    2026
# 16    2026
# 17    2026
# 18    2026
# 19    2026
# 20    2026
# 21    2026
# 22    2026
# 23    2026
# 24    2026
# 25    2026
# Name: sales_date, dtype: int32
