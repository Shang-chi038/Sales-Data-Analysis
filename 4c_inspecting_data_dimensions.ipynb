# %%
# 1 - Confirming that pandas is installed

import pandas as pd

print(pd.__version__)
# Out:
# 2.2.2

# %%
# 2 - Load the sales_data_2
df = pd.read_csv('sales_data_2.csv')

# %%
# 3 - Get the Dimensions of the DataFrame

dimensions = df.shape

# %%
# 4 - Extract Rows and Columns

num_rows = dimensions[0]
num_cols = dimensions[1]

# %%
# 5 - Print the Results

print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_cols}")
# Out:
# Number of rows: 26
# Number of columns: 5
